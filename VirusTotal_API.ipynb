# %% [markdown]
# <a href="https://colab.research.google.com/github/ryanoleary26/VirusTotal-Payload-Scanner/blob/master/VirusTotal_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Analysing Honeypot Payloads with the VirusTotal API
#
# Any files that are given to this script in a .ZIP file will be indivually sent to VirusTotal for scanning using [their v2 API](https://developers.virustotal.com/reference).
#
# #Features
#
#
#
# 1. Displays scan reports from over [70 different Antivirus products](https://support.virustotal.com/hc/en-us/articles/115002146809-Contributors).
# 2. Provides a URL to each indivudual scan performed.
# 3. Provides statitistics on total scans performed and total positive results.
# 4. Ideal for analysis of malicious files collected through honeypots.
# 5. Basic API quota usage detection
# 6. Option to show scan results from specific Antivirus scanners instead of an overall summary.
#
# #Prerequesites
#
# 1. Python
# 2. [Requests](https://requests.readthedocs.io/en/master/) module
#
# #How to use
#
# 1. To use this script for yourself you will need to obtain a free public API key by [creating an account on the VirusTotal website](https://www.virustotal.com/gui/join-us).
# 2. Enter your API key on line 8, see below:
#
#   ```
#   #Enter API key here ########
#   api_key = '<API KEY HERE>' #
#   ############################
#   ```
# 3. Enter the file path of the ZIP file you wish to use on line 16, see below. Note that currentlyy files that are contained within sub-directories of the ZIP file are currently not scanned. To get round this seperate groups of files into seperate ZIP files until I implement this feature.
# ```
#   #Enter the location of your .ZIP file here ######
#   with ZipFile('<FILE PATH HERE>', 'r') as zipObj:#
#   #################################################
# ```
# 4. Line 12 contains a dictionary of Antivirus (AV) names to include in the scan output. Add or remove Antivirus names from this dictionary as you please. The default configuration will include Avast, AVG, BitDefender, FireEye, F-Secure, McAfee and Microsoft in the specific scan result output. This **IS** case sensitive.
# ```
# #Customise the scan output by changing the included AV names here. This IS case and space sensitive.
# antiviruses = {'Avast', 'AVG', 'BitDefender', 'FireEye', 'F-Secure', 'Malwarebytes', 'McAfee', 'Microsoft'}
# ```
# 5. Run the script and enjoy the sexy Antivirus results - Happy Virus Hunting!

# %%
import json
from zipfile import ZipFile
import time
import requests
import os

#Enter API key here ########
api_key = '<API KEY HERE>' #
############################ 

#Customise the scan output by changing the included AV names here. This IS case and space sensitive.########
antiviruses = {'Avast', 'AVG', 'BitDefender', 'FireEye', 'F-Secure', 'Malwarebytes', 'McAfee', 'Microsoft'}#
############################################################################################################

#Enter the location of your .ZIP file here ######
with ZipFile('<FILE PATH HERE>', 'r') as zipObj:#
#################################################

  # Extract all the contents of zip file in different directory
  hashList = zipObj.namelist()

print('##############################################################################################################\n')
payloadNo = 0

#Tracks overall stats
class Stats:
  def __init__ (self):
    self.positiveResult = 0
    self.negativeResult = 0
    self.noResult = 0
    self.extensionsFound = {}

  positiveResult = 0
  negativeResult = 0
  noResult = 0
  extensionsFound = {}

try:
  for payload in hashList:
      payloadNo += 1
      #Makes request to virustotal to scan file
      url = 'https://www.virustotal.com/vtapi/v2/file/report'
      params = {'apikey': api_key, 'resource': payload, 'allinfo': 1}
      try:
        response = requests.get(url, params=params)
        vt_response = response.json()
      except:
        if response.status_code == 204:
        #Handles the 204 response code
          print('Recieved HTTP Response Code:', response.status_code, '-- Indicates that API usage quota has been used up.\nRefer to the VirusTotal API documentation for error description.\nDocumentation link: https://developers.virustotal.com/reference#api-responses')
          break
        else:
          print('JSON Decoder Error')
          break

      #Parsing the JSON response
      print('Scanning Payload {0}/{1}: {2}'.format( payloadNo, len(hashList),payload))
      
      if vt_response['response_code'] == 1:
        print('Scan initiated at', vt_response['scan_date'])
        #Doesn't post AV results if there are zero positive results
        if vt_response['positives'] == 0:
          print('\nAll scans returned negative.')
          Stats.negativeResult += 1
        else:
          print('=== Antivirus Results ===')
          #Loops through selected AVs for detection results
          for av in antiviruses:
            try:
              print(av, '-> Detected:', vt_response['scans'][av]['detected'], ' Result:', vt_response['scans'][av]['result'])
            except KeyError:
              #AVs included in 'antiviruses' might not always return scan results, which will cause a TypeError
              print(av, 'could not return any test results.')

          #Icrease the threshold of a 'positive' match for malware to something like 5? 
          #to avoid a single rouge AV from spoiling results    
          Stats.positiveResult += 1

        print('\n=== Scan Results ===')
        print('Total Scans:', vt_response['total'])
        print('Total Positive Results:', vt_response['positives'])
        print('First seen:', vt_response['first_seen'])
        print('Times Submitted:', vt_response['times_submitted'])
        print('Scan Permalink: ', vt_response['permalink'], '\n')
      
        print('=== EXIF Data provided by https://exiftool.org/ ===')
        try:
          print('File Type/Extension: {} (.{})'.format(vt_response['additional_info']['exiftool']['FileType'], vt_response['additional_info']['exiftool']['FileTypeExtension']))
          
          extension = Stats.extensionsFound.get(vt_response['additional_info']['exiftool']['FileType'], 0)
          extension += 1
          Stats.extensionsFound[vt_response['additional_info']['exiftool']['FileType']] = extension
          
          print('File Size:', round(vt_response['size']/1024/1024,2), 'MB')
          
          print('Description:', vt_response['additional_info']['magic'])
          print('Target Operating System:', vt_response['additional_info']['exiftool']['OperatingSystem'])
          
        except KeyError as err:
          print('\nSome EXIF data was not found :(\n')
        
      #Handles other response codes: https://developers.virustotal.com/reference#api-responses
      elif vt_response['response_code'] != 1:
        print('===========================================================================\n',vt_response['verbose_msg'],'\n===========================================================================')
        Stats.noResult += 1
      print('\n##############################################################################################################\n')

      #Sleeps script to comply with API user agreement
      #Set to 15 for public API, 4.5 for Academic/Premium API
      time.sleep(0)

  #Generic exception handling :/
except KeyboardInterrupt:
  print('Keyboard Interrupt')
print('Scan complete')
#Show intersting scan stats
print('=== Scan Report ===')
print('{0} files were scanned'.format(payloadNo))
print('{0} positive matches were found for malicous files'.format(Stats.positiveResult))
print('{0} negative matches were found for malicous files'.format(Stats.negativeResult))
print('{0} scans had no result due to files still being analysed.'.format(Stats.noResult))
print('List of different file extensions found:')

#Show each file extension found
for ext in Stats.extensionsFound:
  print('   {0}: {1}'.format(ext,Stats.extensionsFound[ext]))
# Out:
# ##############################################################################################################
#
# Scanning Payload 1/1391: 0013d4e2ee63e2be651c99071bb3207c5acef4b9aa1e135e8f19eba656e68d1a
# Scan initiated at 2020-05-01 16:48:52
#
# All scans returned negative.
#
# === Scan Results ===
# Total Scans: 58
# Total Positive Results: 0
# First seen: 2020-01-13 19:08:22
# Times Submitted: 3
# Scan Permalink:  https://www.virustotal.com/file/0013d4e2ee63e2be651c99071bb3207c5acef4b9aa1e135e8f19eba656e68d1a/analysis/1588351732/
#
# === EXIF Data provided by https://exiftool.org/ ===
# File Type/Extension: GZIP (.gz)
# File Size: 2.77 MB
# Description: gzip compressed data, from Unix, last modified: Mon Jan 06 15:07:35 2020
# Target Operating System: Unix
#
# ##############################################################################################################
#
# Scanning Payload 2/1391: 00ce2b7587eb0ff6663f57ed5d59ceabacad865f1c06b4ca8c8c7416b74b7b5a
# Scan initiated at 2019-09-27 13:46:19
#
# All scans returned negative.
#
# === Scan Results ===
# Total Scans: 56
# Total Positive Results: 0
# First seen: 2019-09-27 13:46:19
# Times Submitted: 1
# Scan Permalink:  https://www.virustotal.com/file/00ce2b7587eb0ff6663f57ed5d59ceabacad865f1c06b4ca8c8c7416b74b7b5a/analysis/1569591979/
#
# === EXIF Data provided by https://exiftool.org/ ===
# File Type/Extension: GZIP (.gz)
# File Size: 0.83 MB
# Description: gzip compressed data, from Unix, last modified: Tue Sep 03 13:02:03 2019
# Target Operating System: Unix
#
# ##############################################################################################################
#
# Scanning Payload 3/1391: 00ffa6929a9d124bf8b58ecde36771f04fb9366f89f555ba7e7f95abb81c04e0
# Scan initiated at 2020-05-01 16:46:50
# === Antivirus Results ===
# FireEye -> Detected: True  Result: Trojan.Linux.Generic.109316
# F-Secure -> Detected: True  Result: Malware.LINUX/Agent.etkyc
# AVG -> Detected: True  Result: ELF:BruteForce-I [Trj]
# McAfee -> Detected: True  Result: GenericRXIK-UY!5AE1BB025000
# BitDefender -> Detected: True  Result: Trojan.GenericKD.33737877
# Avast -> Detected: True  Result: ELF:BruteForce-I [Trj]
# Malwarebytes -> Detected: False  Result: None
# Microsoft -> Detected: True  Result: Trojan:Linux/CoinMiner!rfn
#
# === Scan Results ===
# Total Scans: 58
# Total Positive Results: 24
# First seen: 2019-09-04 02:52:14
# Times Submitted: 5
# Scan Permalink:  https://www.virustotal.com/file/00ffa6929a9d124bf8b58ecde36771f04fb9366f89f555ba7e7f95abb81c04e0/analysis/1588351610/
#
# === EXIF Data provided by https://exiftool.org/ ===
# File Type/Extension: GZIP (.gz)
# File Size: 3.24 MB
# Description: gzip compressed data, from Unix, last modified: Tue Sep 03 13:02:03 2019
# Target Operating System: Unix
#
# ##############################################################################################################
#
# Scanning Payload 4/1391: 012f70a2b67b0fa6f7bfc75896570f538f65affdedd5499e21ffa19c1fdc6449
# Scan initiated at 2019-08-16 18:07:49
# === Antivirus Results ===
# FireEye -> Detected: False  Result: None
# F-Secure -> Detected: True  Result: Malware.LINUX/Agent.etkyc
# AVG -> Detected: True  Result: ELF:BruteForce-I [Trj]
# McAfee -> Detected: True  Result: Linux/CoinMiner.y
# BitDefender -> Detected: False  Result: None
# Avast -> Detected: True  Result: ELF:BruteForce-I [Trj]
# Malwarebytes -> Detected: False  Result: None
# Microsoft -> Detected: True  Result: Trojan:Win32/Zpevdo.B
#
# === Scan Results ===
# Total Scans: 58
# Total Positive Results: 17
# First seen: 2019-08-16 18:07:49
# Times Submitted: 1
# Scan Permalink:  https://www.virustotal.com/file/012f70a2b67b0fa6f7bfc75896570f538f65affdedd5499e21ffa19c1fdc6449/analysis/1565978869/
#
# === EXIF Data provided by https://exiftool.org/ ===
# File Type/Extension: GZIP (.gz)
# File Size: 4.91 MB
# Description: gzip compressed data, from Unix, last modified: Wed Aug 14 20:18:29 2019
# Target Operating System: Unix
#
# ##############################################################################################################
#
# Scanning Payload 5/1391: 0160eebf82f657ebc6af6be154cfcf4ec41f7b5b50a28882149d882fdcd5e3ac
# Scan initiated at 2020-02-19 05:52:37
# === Antivirus Results ===
# FireEye -> Detected: True  Result: Trojan.Linux.Generic.159792
# F-Secure -> Detected: True  Result: Malware.LINUX/Agent.mxfdv
# AVG -> Detected: True  Result: ELF:BruteForce-I [Trj]
# McAfee -> Detected: True  Result: GenericRXIK-UY!4C2388FACF00
# BitDefender -> Detected: True  Result: Trojan.Linux.Generic.159792
# Avast -> Detected: True  Result: ELF:BruteForce-I [Trj]
# Malwarebytes -> Detected: False  Result: None
# Microsoft -> Detected: True  Result: Trojan:Win32/Occamy.C
#
# === Scan Results ===
# Total Scans: 60
# Total Positive Results: 21
# First seen: 2020-02-19 05:52:37
# Times Submitted: 1
# Scan Permalink:  https://www.virustotal.com/file/0160eebf82f657ebc6af6be154cfcf4ec41f7b5b50a28882149d882fdcd5e3ac/analysis/1582091557/
#
# === EXIF Data provided by https://exiftool.org/ ===
# File Type/Extension: GZIP (.gz)
# File Size: 3.88 MB
# Description: gzip compressed data, from Unix, last modified: Sun Feb 16 11:12:35 2020
# Target Operating System: Unix
#
# ##############################################################################################################
#
# Scanning Payload 6/1391: 016c1f63e89144014f22d3ff02e1e7e692b2e40df783d603130ecf7387cd5449
# Scan initiated at 2020-05-01 16:47:27
# === Antivirus Results ===
# FireEye -> Detected: True  Result: Trojan.Linux.Generic.109316
# F-Secure -> Detected: True  Result: Malware.LINUX/Agent.etkyc
# AVG -> Detected: True  Result: ELF:BruteForce-I [Trj]
# McAfee -> Detected: True  Result: GenericRXIK-UY!5AE1BB025000
# BitDefender -> Detected: True  Result: Trojan.Linux.Generic.109316
# Avast -> Detected: True  Result: ELF:BruteForce-I [Trj]
# Malwarebytes -> Detected: False  Result: None
# Microsoft -> Detected: True  Result: Trojan:Win32/Occamy.C
#
# === Scan Results ===
# Total Scans: 60
# Total Positive Results: 24
# First seen: 2019-08-16 18:49:43
# Times Submitted: 5
# Scan Permalink:  https://www.virustotal.com/file/016c1f63e89144014f22d3ff02e1e7e692b2e40df783d603130ecf7387cd5449/analysis/1588351647/
#
# === EXIF Data provided by https://exiftool.org/ ===
# File Type/Extension: GZIP (.gz)
# File Size: 3.4 MB
# Description: gzip compressed data, from Unix, last modified: Wed Aug 14 20:18:29 2019
# Target Operating System: Unix
#
# ##############################################################################################################
#
# Scanning Payload 7/1391: 0171b4e33e72888b0a3db799aed2fa9421f83bc61c2007a9d15be39813854472
# Scan initiated at 2020-05-01 16:48:11
# === Antivirus Results ===
# FireEye -> Detected: False  Result: None
# F-Secure -> Detected: True  Result: Malware.LINUX/Agent.oytek
# AVG -> Detected: True  Result: ELF:BruteForce-I [Trj]
# McAfee -> Detected: False  Result: None
# BitDefender -> Detected: True  Result: Trojan.Linux.Generic.168341
# Avast -> Detected: True  Result: ELF:BruteForce-I [Trj]
# Malwarebytes -> Detected: False  Result: None
# Microsoft -> Detected: True  Result: Trojan:Script/Wacatac.C!ml
#
# === Scan Results ===
# Total Scans: 59
# Total Positive Results: 22
# First seen: 2020-03-15 22:55:51
# Times Submitted: 2
# Scan Permalink:  https://www.virustotal.com/file/0171b4e33e72888b0a3db799aed2fa9421f83bc61c2007a9d15be39813854472/analysis/1588351691/
#
# === EXIF Data provided by https://exiftool.org/ ===
# File Type/Extension: GZIP (.gz)
# File Size: 2.8 MB
# Description: gzip compressed data, from Unix, last modified: Sun Mar 15 17:44:15 2020
# Target Operating System: Unix
#
# ##############################################################################################################
#
# Scanning Payload 8/1391: 017fca6d7a13a3cdbae938399372d232f52946704e2f154eb56a43035c1b23cf
# Scan initiated at 2019-08-17 10:11:19
#
# All scans returned negative.
#
# === Scan Results ===
# Total Scans: 57
# Total Positive Results: 0
# First seen: 2019-08-17 10:11:19
# Times Submitted: 1
# Scan Permalink:  https://www.virustotal.com/file/017fca6d7a13a3cdbae938399372d232f52946704e2f154eb56a43035c1b23cf/analysis/1566036679/
#
# === EXIF Data provided by https://exiftool.org/ ===
# File Type/Extension: GZIP (.gz)
# File Size: 2.14 MB
# Description: gzip compressed data, from Unix, last modified: Wed Aug 14 20:18:29 2019
# Target Operating System: Unix
#
# ##############################################################################################################
#
# Scanning Payload 9/1391: 018acf2a5a3f876edcf8ee427ab803012bc28cc622d16d69b8018f628f5d845f
# ===========================================================================
#  The requested resource is not among the finished, queued or pending scans
# ===========================================================================
#
# ##############################################################################################################
#
# Scanning Payload 10/1391: 0193f4542397f19f0af16a9e2353801b382f8ad10f3fa4117a8da83ab77299fc
# Scan initiated at 2020-05-01 16:48:30
# === Antivirus Results ===
# FireEye -> Detected: True  Result: Trojan.Linux.Generic.167416
# F-Secure -> Detected: True  Result: Malware.LINUX/Agent.qcvrq
# AVG -> Detected: True  Result: ELF:BruteForce-I [Trj]
# McAfee -> Detected: True  Result: GenericRXIK-UY!E2611512B4F9
# BitDefender -> Detected: True  Result: Trojan.Linux.Generic.167416
# Avast -> Detected: True  Result: ELF:BruteForce-I [Trj]
# Malwarebytes -> Detected: False  Result: None
# Microsoft -> Detected: True  Result: Trojan:Linux/CoinMiner!rfn
#
# === Scan Results ===
# Total Scans: 59
# Total Positive Results: 25
# First seen: 2020-03-17 19:26:19
# Times Submitted: 2
# Scan Permalink:  https://www.virustotal.com/file/0193f4542397f19f0af16a9e2353801b382f8ad10f3fa4117a8da83ab77299fc/analysis/1588351710/
#
# === EXIF Data provided by https://exiftool.org/ ===
# File Type/Extension: GZIP (.gz)
# File Size: 2.93 MB
# Description: gzip compressed data, from Unix, last modified: Tue Mar 17 15:05:34 2020
# Target Operating System: Unix
#
# ##############################################################################################################
#
# Scanning Payload 11/1391: 019c3120a94f2ceceab3cca5ca87efe8b1838be9e6f494773ee6735f08062241
# Scan initiated at 2019-10-01 19:28:27
#
# All scans returned negative.
#
# === Scan Results ===
# Total Scans: 56
# Total Positive Results: 0
# First seen: 2019-08-17 07:27:15
# Times Submitted: 2
# Scan Permalink:  https://www.virustotal.com/file/019c3120a94f2ceceab3cca5ca87efe8b1838be9e6f494773ee6735f08062241/analysis/1569958107/
#
# === EXIF Data provided by https://exiftool.org/ ===
# File Type/Extension: GZIP (.gz)
# File Size: 2.09 MB
# Description: gzip compressed data, from Unix, last modified: Wed Aug 14 20:18:29 2019
# Target Operating System: Unix
#
# ##############################################################################################################
#
# Scanning Payload 12/1391: 02477e1ab4520647f3ca174bf3ebd9fa962579653174f7350eda7262fd539e9e
# Scan initiated at 2020-01-21 17:20:29
#
# All scans returned negative.
#
# === Scan Results ===
# Total Scans: 59
# Total Positive Results: 0
# First seen: 2020-01-07 10:55:19
# Times Submitted: 2
# Scan Permalink:  https://www.virustotal.com/file/02477e1ab4520647f3ca174bf3ebd9fa962579653174f7350eda7262fd539e9e/analysis/1579627229/
#
# === EXIF Data provided by https://exiftool.org/ ===
# File Type/Extension: GZIP (.gz)
# File Size: 0.04 MB
# Description: gzip compressed data, from Unix, last modified: Mon Jan 06 15:07:35 2020
# Target Operating System: Unix
#
# ##############################################################################################################
#
# Scanning Payload 13/1391: 0247ad15f4691d5b2f700c12aacb2da19b16faa5b37e949a1b1470e581e2032f
# Scan initiated at 2020-01-10 22:21:53
#
# All scans returned negative.
#
# === Scan Results ===
# Total Scans: 59
# Total Positive Results: 0
# First seen: 2020-01-10 22:21:53
# Times Submitted: 1
# Scan Permalink:  https://www.virustotal.com/file/0247ad15f4691d5b2f700c12aacb2da19b16faa5b37e949a1b1470e581e2032f/analysis/1578694913/
#
# === EXIF Data provided by https://exiftool.org/ ===
# File Type/Extension: TXT (.txt)
# File Size: 0.0 MB
# Description: ASCII text
#
# Some EXIF data was not found :(
#
#
# ##############################################################################################################
#
# Scanning Payload 14/1391: 025eed745d2991b6b081614153f309e9492dfd12c772ae72d0af4bde37786db1
# Scan initiated at 2020-01-05 21:26:05
#
# All scans returned negative.
#
# === Scan Results ===
# Total Scans: 60
# Total Positive Results: 0
# First seen: 2019-08-16 13:36:22
# Times Submitted: 3
# Scan Permalink:  https://www.virustotal.com/file/025eed745d2991b6b081614153f309e9492dfd12c772ae72d0af4bde37786db1/analysis/1578259565/
#
# === EXIF Data provided by https://exiftool.org/ ===
# File Type/Extension: GZIP (.gz)
# File Size: 2.16 MB
# Description: gzip compressed data, from Unix, last modified: Wed Aug 14 20:18:29 2019
# Target Operating System: Unix
#
# ##############################################################################################################
#
# Scanning Payload 15/1391: 02716d3b2dad0e4e4c2a57407c135d4161b3d747834f8817020705c306f2fa58
# Scan initiated at 2019-11-28 07:49:18
#
# All scans returned negative.
#
# === Scan Results ===
# Total Scans: 57
# Total Positive Results: 0
# First seen: 2019-11-28 07:49:18
# Times Submitted: 1
# Scan Permalink:  https://www.virustotal.com/file/02716d3b2dad0e4e4c2a57407c135d4161b3d747834f8817020705c306f2fa58/analysis/1574927358/
#
# === EXIF Data provided by https://exiftool.org/ ===
# File Type/Extension: TXT (.txt)
# File Size: 0.0 MB
# Description: ASCII text
#
# Some EXIF data was not found :(
#
#
# ##############################################################################################################
#
# Scanning Payload 16/1391: 0271f4fbd2436125c4caa445e792479c2e6872d77effe4a96bb677b8eda93583
# ===========================================================================
#  The requested resource is not among the finished, queued or pending scans
# ===========================================================================
#
# ##############################################################################################################
#
# Scanning Payload 17/1391: 028e3caa0d9bff97fc4db2c2755f159755ea6882f9cf6e3be1958ed87e196479
# Scan initiated at 2019-09-24 18:38:25
#
# All scans returned negative.
#
# === Scan Results ===
# Total Scans: 57
# Total Positive Results: 0
# First seen: 2019-08-17 04:09:40
# Times Submitted: 2
# Scan Permalink:  https://www.virustotal.com/file/028e3caa0d9bff97fc4db2c2755f159755ea6882f9cf6e3be1958ed87e196479/analysis/1569350305/
#
# === EXIF Data provided by https://exiftool.org/ ===
# File Type/Extension: GZIP (.gz)
# File Size: 2.21 MB
# Description: gzip compressed data, from Unix, last modified: Wed Aug 14 20:18:29 2019
# Target Operating System: Unix
#
# ##############################################################################################################
#
# Scanning Payload 18/1391: 02df473139dc051628ffac898606f841356d708252c4952bdd76c4f9b3b44c50
# Scan initiated at 2020-01-28 13:54:43
#
# All scans returned negative.
#
# === Scan Results ===
# Total Scans: 58
# Total Positive Results: 0
# First seen: 2019-08-16 16:28:26
# Times Submitted: 3
# Scan Permalink:  https://www.virustotal.com/file/02df473139dc051628ffac898606f841356d708252c4952bdd76c4f9b3b44c50/analysis/1580219683/
#
# === EXIF Data provided by https://exiftool.org/ ===
# File Type/Extension: GZIP (.gz)
# File Size: 2.46 MB
# Description: gzip compressed data, from Unix, last modified: Wed Aug 14 20:18:29 2019
# Target Operating System: Unix
#
# ##############################################################################################################
#
# Scanning Payload 19/1391: 02e19fa224460438e4b0eb99262ddfa3c1f57770c145143d16149d11320ffa1e
# Scan initiated at 2019-10-01 19:31:38
#
# All scans returned negative.
#
# === Scan Results ===
# Total Scans: 56
# Total Positive Results: 0
# First seen: 2019-08-15 00:09:16
# Times Submitted: 2
# Scan Permalink:  https://www.virustotal.com/file/02e19fa224460438e4b0eb99262ddfa3c1f57770c145143d16149d11320ffa1e/analysis/1569958298/
#
# === EXIF Data provided by https://exiftool.org/ ===
# File Type/Extension: GZIP (.gz)
# File Size: 2.45 MB
# Description: gzip compressed data, from Unix, last modified: Wed Aug 14 20:18:29 2019
# Target Operating System: Unix
#
# ##############################################################################################################
#
# Scanning Payload 20/1391: 02e77c572b7cf3b2e4aa5c7c483427df5684f327ab43c26cf05a702e89a08072
# Scan initiated at 2020-01-11 20:44:30
# === Antivirus Results ===
# FireEye -> Detected: True  Result: Trojan.Linux.Generic.151688
# F-Secure -> Detected: True  Result: Malware.LINUX/Agent.mxfdv
# AVG -> Detected: True  Result: ELF:BruteForce-I [Trj]
# McAfee -> Detected: True  Result: GenericRXIK-UY!4C2388FACF00
# BitDefender -> Detected: True  Result: Trojan.Linux.Generic.155029
# Avast -> Detected: True  Result: ELF:BruteForce-I [Trj]
# Malwarebytes -> Detected: False  Result: None
# Microsoft -> Detected: True  Result: Trojan:Win32/Ditertag.A
#
# === Scan Results ===
# Total Scans: 58
# Total Positive Results: 20
# First seen: 2020-01-11 20:44:30
# Times Submitted: 1
# Scan Permalink:  https://www.virustotal.com/file/02e77c572b7cf3b2e4aa5c7c483427df5684f327ab43c26cf05a702e89a08072/analysis/1578775470/
#
# === EXIF Data provided by https://exiftool.org/ ===
# File Type/Extension: GZIP (.gz)
# File Size: 7.76 MB
# Description: gzip compressed data, from Unix, last modified: Mon Jan 06 15:07:35 2020
# Target Operating System: Unix
#
# ##############################################################################################################
#
# Scanning Payload 21/1391: 02f2a1feee14d07c716271fa2d956f93f10def40c73b2895d33f87d6fc3e6ff1
# Scan initiated at 2020-05-01 16:46:46
# === Antivirus Results ===
# FireEye -> Detected: True  Result: Trojan.Linux.Generic.167416
# F-Secure -> Detected: True  Result: Malware.LINUX/Agent.qcvrq
# AVG -> Detected: True  Result: ELF:BruteForce-I [Trj]
# McAfee -> Detected: True  Result: GenericRXIK-UY!E2611512B4F9
# BitDefender -> Detected: True  Result: Trojan.Linux.Generic.167416
# Avast -> Detected: True  Result: ELF:BruteForce-I [Trj]
# Malwarebytes -> Detected: False  Result: None
# Microsoft -> Detected: True  Result: Trojan:Linux/CoinMiner!rfn
#
# === Scan Results ===
# Total Scans: 59
# Total Positive Results: 25
# First seen: 2020-03-17 20:20:20
# Times Submitted: 2
# Scan Permalink:  https://www.virustotal.com/file/02f2a1feee14d07c716271fa2d956f93f10def40c73b2895d33f87d6fc3e6ff1/analysis/1588351606/
#
# === EXIF Data provided by https://exiftool.org/ ===
# File Type/Extension: GZIP (.gz)
# File Size: 3.25 MB
# Description: gzip compressed data, from Unix, last modified: Tue Mar 17 15:05:34 2020
# Target Operating System: Unix
#
# ##############################################################################################################
#
# Scanning Payload 22/1391: 02f718b9f6f6777ec29eee9d871eecd60d4822f7cf2a2e042d04407dc5404755
# Scan initiated at 2019-08-15 20:33:26
#
# All scans returned negative.
#
# === Scan Results ===
# Total Scans: 52
# Total Positive Results: 0
# First seen: 2019-08-15 20:33:26
# Times Submitted: 1
# Scan Permalink:  https://www.virustotal.com/file/02f718b9f6f6777ec29eee9d871eecd60d4822f7cf2a2e042d04407dc5404755/analysis/1565901206/
#
# === EXIF Data provided by https://exiftool.org/ ===
# File Type/Extension: GZIP (.gz)
# File Size: 2.19 MB
# Description: gzip compressed data, from Unix, last modified: Wed Aug 14 20:18:29 2019
# Target Operating System: Unix
#
# ##############################################################################################################
#
# Scanning Payload 23/1391: 03231b03c00135d5d4eb0c1c1c9314705c14b0be6b05cb190ee8362d8975d5ef
# Scan initiated at 2019-08-17 19:43:50
# === Antivirus Results ===
# FireEye -> Detected: False  Result: None
# F-Secure -> Detected: True  Result: Malware.LINUX/Agent.etkyc
# AVG -> Detected: True  Result: ELF:BruteForce-I [Trj]
# McAfee -> Detected: False  Result: None
# BitDefender -> Detected: False  Result: None
# Avast -> Detected: True  Result: ELF:BruteForce-I [Trj]
# Malwarebytes -> Detected: False  Result: None
# Microsoft -> Detected: True  Result: Trojan:Win32/Zpevdo.B
#
# === Scan Results ===
# Total Scans: 55
# Total Positive Results: 11
# First seen: 2019-08-17 19:43:50
# Times Submitted: 1
# Scan Permalink:  https://www.virustotal.com/file/03231b03c00135d5d4eb0c1c1c9314705c14b0be6b05cb190ee8362d8975d5ef/analysis/1566071030/
#
# === EXIF Data provided by https://exiftool.org/ ===
# File Type/Extension: GZIP (.gz)
# File Size: 3.89 MB
# Description: gzip compressed data, from Unix, last modified: Wed Aug 14 20:18:29 2019
# Target Operating System: Unix
#
# ##############################################################################################################
#
# Scanning Payload 24/1391: 03873cce9ae48f6fa3e811cc026e8ea25ec6cbb1f65cdc305d96e247080c6dc8
# Scan initiated at 2019-08-17 14:51:01
#
# All scans returned negative.
#
# === Scan Results ===
# Total Scans: 57
# Total Positive Results: 0
# First seen: 2019-08-17 14:51:01
# Times Submitted: 1
# Scan Permalink:  https://www.virustotal.com/file/03873cce9ae48f6fa3e811cc026e8ea25ec6cbb1f65cdc305d96e247080c6dc8/analysis/1566053461/
#
# === EXIF Data provided by https://exiftool.org/ ===
#
# Some EXIF data was not found :(
#
#
# ##############################################################################################################
#
# Scanning Payload 25/1391: 0389cc5946ac9195400ecdce3550dd181da0308456a15c6489e2d63cc2b279b7
# Scan initiated at 2020-05-01 16:48:48
# === Antivirus Results ===
# FireEye -> Detected: False  Result: None
# F-Secure -> Detected: False  Result: None
# AVG -> Detected: False  Result: None
# McAfee -> Detected: False  Result: None
# BitDefender -> Detected: False  Result: None
# Avast -> Detected: False  Result: None
# Malwarebytes -> Detected: False  Result: None
# Microsoft -> Detected: False  Result: None
#
# === Scan Results ===
# Total Scans: 60
# Total Positive Results: 3
# First seen: 2019-08-17 06:14:38
# Times Submitted: 2
# Scan Permalink:  https://www.virustotal.com/file/0389cc5946ac9195400ecdce3550dd181da0308456a15c6489e2d63cc2b279b7/analysis/1588351728/
#
# === EXIF Data provided by https://exiftool.org/ ===
# File Type/Extension: GZIP (.gz)
# File Size: 2.62 MB
# Description: gzip compressed data, from Unix, last modified: Wed Aug 14 20:18:29 2019
# Target Operating System: Unix
#
# ##############################################################################################################
#
# Scanning Payload 26/1391: 03a5757dc0eb66cf2e5984662dead4db55b8958dd849f6537534c40387ac3370
# Scan initiated at 2019-10-01 19:32:58
# === Antivirus Results ===
# FireEye -> Detected: False  Result: None
# F-Secure -> Detected: True  Result: Malware.LINUX/Agent.etkyc
# AVG -> Detected: True  Result: ELF:BruteForce-I [Trj]
# McAfee -> Detected: True  Result: GenericRXIK-UY!5AE1BB025000
# BitDefender -> Detected: False  Result: None
# Avast -> Detected: True  Result: ELF:BruteForce-I [Trj]
# Malwarebytes -> Detected: False  Result: None
# Microsoft -> Detected: True  Result: Trojan:Win32/Tiggre!plock
#
# === Scan Results ===
# Total Scans: 56
# Total Positive Results: 18
# First seen: 2019-08-19 20:27:33
# Times Submitted: 2
# Scan Permalink:  https://www.virustotal.com/file/03a5757dc0eb66cf2e5984662dead4db55b8958dd849f6537534c40387ac3370/analysis/1569958378/
#
# === EXIF Data provided by https://exiftool.org/ ===
# File Type/Extension: GZIP (.gz)
# File Size: 3.71 MB
# Description: gzip compressed data, from Unix, last modified: Wed Aug 14 20:18:29 2019
# Target Operating System: Unix
#
# ##############################################################################################################
#
# Scanning Payload 27/1391: 0492edb87f6089082eff9faec51c942e89a1da6c5c789a3f7fee8d974e8afce7
# Scan initiated at 2019-08-18 09:48:46
#
# All scans returned negative.
#
# === Scan Results ===
# Total Scans: 55
# Total Positive Results: 0
# First seen: 2019-08-18 09:48:46
# Times Submitted: 1
# Scan Permalink:  https://www.virustotal.com/file/0492edb87f6089082eff9faec51c942e89a1da6c5c789a3f7fee8d974e8afce7/analysis/1566121726/
#
# === EXIF Data provided by https://exiftool.org/ ===
#
# Some EXIF data was not found :(
#
#
# ##############################################################################################################
#
# Scanning Payload 28/1391: 04c4b25852eaf2b0e5e324379cf23fc02a1c057bfb439a57c033aadeaa5f15cb
# Scan initiated at 2020-01-13 03:57:51
#
# All scans returned negative.
#
# === Scan Results ===
# Total Scans: 59
# Total Positive Results: 0
# First seen: 2020-01-13 03:57:51
# Times Submitted: 1
# Scan Permalink:  https://www.virustotal.com/file/04c4b25852eaf2b0e5e324379cf23fc02a1c057bfb439a57c033aadeaa5f15cb/analysis/1578887871/
#
# === EXIF Data provided by https://exiftool.org/ ===
# File Type/Extension: TXT (.txt)
# File Size: 0.0 MB
# Description: ASCII text
#
# Some EXIF data was not found :(
#
#
# ##############################################################################################################
#
# Scanning Payload 29/1391: 05004f80e36ad3b0c30a2f9d6a45629b442d62263a136b48108e9c3cc6283596
# Scan initiated at 2019-08-16 16:46:43
#
# All scans returned negative.
#
# === Scan Results ===
# Total Scans: 56
# Total Positive Results: 0
# First seen: 2019-08-16 16:46:43
# Times Submitted: 1
# Scan Permalink:  https://www.virustotal.com/file/05004f80e36ad3b0c30a2f9d6a45629b442d62263a136b48108e9c3cc6283596/analysis/1565974003/
#
# === EXIF Data provided by https://exiftool.org/ ===
#
# Some EXIF data was not found :(
#
#
# ##############################################################################################################
#
# Scanning Payload 30/1391: 05055fe525bf6b6e42e75fd65d3e30fa797da6ec4ee27be7c49ecaaeee199729
# Scan initiated at 2020-01-22 05:02:10
#
# All scans returned negative.
#
# === Scan Results ===
# Total Scans: 59
# Total Positive Results: 0
# First seen: 2020-01-11 03:05:39
# Times Submitted: 2
# Scan Permalink:  https://www.virustotal.com/file/05055fe525bf6b6e42e75fd65d3e30fa797da6ec4ee27be7c49ecaaeee199729/analysis/1579669330/
#
# === EXIF Data provided by https://exiftool.org/ ===
# File Type/Extension: GZIP (.gz)
# File Size: 2.92 MB
# Description: gzip compressed data, from Unix, last modified: Mon Jan 06 15:07:35 2020
# Target Operating System: Unix
#
# ##############################################################################################################
#
# Scanning Payload 31/1391: 051a373057d7b653bf30e810bddca978dd4d3ae28051ba4974c3b1866b8d1976
# Scan initiated at 2020-05-01 16:46:38
#
# All scans returned negative.
#
# === Scan Results ===
# Total Scans: 59
# Total Positive Results: 0
# First seen: 2020-01-06 20:50:16
# Times Submitted: 3
# Scan Permalink:  https://www.virustotal.com/file/051a373057d7b653bf30e810bddca978dd4d3ae28051ba4974c3b1866b8d1976/analysis/1588351598/
#
# === EXIF Data provided by https://exiftool.org/ ===
# File Type/Extension: GZIP (.gz)
# File Size: 2.61 MB
# Description: gzip compressed data, from Unix, last modified: Mon Jan 06 15:07:35 2020
# Target Operating System: Unix
#
# ##############################################################################################################
#
# Scanning Payload 32/1391: 055dfb6ce90679b28aa508ac0971753be317a60421551204825b089f455bec07
# Scan initiated at 2019-08-16 22:16:39
# === Antivirus Results ===
# FireEye -> Detected: False  Result: None
# F-Secure -> Detected: True  Result: Malware.LINUX/Agent.etkyc
# AVG -> Detected: True  Result: ELF:BruteForce-I [Trj]
# McAfee -> Detected: False  Result: None
# BitDefender -> Detected: False  Result: None
# Avast -> Detected: True  Result: ELF:BruteForce-I [Trj]
# Malwarebytes -> Detected: False  Result: None
# Microsoft -> Detected: True  Result: Trojan:Win32/Zpevdo.B
#
# === Scan Results ===
# Total Scans: 57
# Total Positive Results: 10
# First seen: 2019-08-16 22:16:39
# Times Submitted: 1
# Scan Permalink:  https://www.virustotal.com/file/055dfb6ce90679b28aa508ac0971753be317a60421551204825b089f455bec07/analysis/1565993799/
#
# === EXIF Data provided by https://exiftool.org/ ===
# File Type/Extension: GZIP (.gz)
# File Size: 4.04 MB
# Description: gzip compressed data, from Unix, last modified: Wed Aug 14 20:18:29 2019
# Target Operating System: Unix
#
# ##############################################################################################################
#
# Scanning Payload 33/1391: 058b3a3f7184deb18e1caf4f9383f713eb503beed9a46ba8c78460a258d5dfe6
# Scan initiated at 2020-05-01 16:47:22
#
# All scans returned negative.
#
# === Scan Results ===
# Total Scans: 59
# Total Positive Results: 0
# First seen: 2020-01-07 01:24:57
# Times Submitted: 2
# Scan Permalink:  https://www.virustotal.com/file/058b3a3f7184deb18e1caf4f9383f713eb503beed9a46ba8c78460a258d5dfe6/analysis/1588351642/
#
# === EXIF Data provided by https://exiftool.org/ ===
# File Type/Extension: GZIP (.gz)
# File Size: 2.5 MB
# Description: gzip compressed data, from Unix, last modified: Mon Jan 06 15:07:35 2020
# Target Operating System: Unix
#
# ##############################################################################################################
#
# Scanning Payload 34/1391: 059c3138c86d2f55a1893329348b8856b5bf4e47b5edc077b1d9a1d6912c1c6b
# Scan initiated at 2020-05-01 16:48:42
# === Antivirus Results ===
# FireEye -> Detected: True  Result: Trojan.Linux.Generic.167416
# F-Secure -> Detected: True  Result: Malware.LINUX/Agent.qcvrq
# AVG -> Detected: True  Result: ELF:BruteForce-I [Trj]
# McAfee -> Detected: True  Result: GenericRXIK-UY!E2611512B4F9
# BitDefender -> Detected: True  Result: Trojan.Linux.Generic.167416
# Avast -> Detected: True  Result: ELF:BruteForce-I [Trj]
# Malwarebytes -> Detected: False  Result: None
# Microsoft -> Detected: True  Result: Trojan:Linux/CoinMiner!rfn
#
# === Scan Results ===
# Total Scans: 59
# Total Positive Results: 24
# First seen: 2020-03-17 17:16:57
# Times Submitted: 2
# Scan Permalink:  https://www.virustotal.com/file/059c3138c86d2f55a1893329348b8856b5bf4e47b5edc077b1d9a1d6912c1c6b/analysis/1588351722/
#
# === EXIF Data provided by https://exiftool.org/ ===
# File Type/Extension: GZIP (.gz)
# File Size: 3.35 MB
# Description: gzip compressed data, from Unix, last modified: Tue Mar 17 15:05:34 2020
# Target Operating System: Unix
#
# ##############################################################################################################
#
# Scanning Payload 35/1391: 069a28c78530f92f8282475ae13484e3d3c92804bfd80d31a07a1bda0a366c6d
# ===========================================================================
#  The requested resource is not among the finished, queued or pending scans
# ===========================================================================
#
# ##############################################################################################################
#
# Scanning Payload 36/1391: 06a672ed8acde9db49e944dfa6a767b1e688b07711728fb5b020d003ea16f57a
# Scan initiated at 2020-01-11 14:07:50
#
# All scans returned negative.
#
# === Scan Results ===
# Total Scans: 56
# Total Positive Results: 0
# First seen: 2020-01-11 14:07:50
# Times Submitted: 1
# Scan Permalink:  https://www.virustotal.com/file/06a672ed8acde9db49e944dfa6a767b1e688b07711728fb5b020d003ea16f57a/analysis/1578751670/
#
# === EXIF Data provided by https://exiftool.org/ ===
# File Type/Extension: GZIP (.gz)
# File Size: 1.5 MB
# Description: gzip compressed data, from Unix, last modified: Mon Jan 06 15:07:35 2020
# Target Operating System: Unix
#
# ##############################################################################################################
#
# Scanning Payload 37/1391: 07640531d67c353e469441d2cd24caf603b2d789f183ebed071a5920ce59c1ef
# Scan initiated at 2020-05-01 16:48:19
#
# All scans returned negative.
#
# === Scan Results ===
# Total Scans: 59
# Total Positive Results: 0
# First seen: 2019-12-31 21:35:40
# Times Submitted: 2
# Scan Permalink:  https://www.virustotal.com/file/07640531d67c353e469441d2cd24caf603b2d789f183ebed071a5920ce59c1ef/analysis/1588351699/
#
# === EXIF Data provided by https://exiftool.org/ ===
# File Type/Extension: GZIP (.gz)
# File Size: 2.4 MB
# Description: gzip compressed data, from Unix, last modified: Mon Dec 23 17:38:17 2019
# Target Operating System: Unix
#
# ##############################################################################################################
#
# Scanning Payload 38/1391: 077bf5d8e69d677de19e4fa1ac44392e2c8410964613abf3cf177fcb59568ea6
# Scan initiated at 2020-05-01 16:47:56
# === Antivirus Results ===
# FireEye -> Detected: False  Result: None
# F-Secure -> Detected: False  Result: None
# AVG -> Detected: False  Result: None
# McAfee -> Detected: False  Result: None
# BitDefender -> Detected: False  Result: None
# Avast -> Detected: False  Result: None
# Malwarebytes -> Detected: False  Result: None
# Microsoft -> Detected: True  Result: Trojan:Win32/Ditertag.A
#
# === Scan Results ===
# Total Scans: 60
# Total Positive Results: 4
# First seen: 2019-11-29 07:27:55
# Times Submitted: 2
# Scan Permalink:  https://www.virustotal.com/file/077bf5d8e69d677de19e4fa1ac44392e2c8410964613abf3cf177fcb59568ea6/analysis/1588351676/
#
# === EXIF Data provided by https://exiftool.org/ ===
# File Type/Extension: GZIP (.gz)
# File Size: 2.66 MB
# Description: gzip compressed data, from Unix, last modified: Sat Nov 23 10:22:39 2019
# Target Operating System: Unix
#
# ##############################################################################################################
#
# Scanning Payload 39/1391: 085ae4ae11ba0200ba961b06c995249006fe0589c42ebf547e24e5987b9cb675
# Scan initiated at 2020-05-01 16:46:57
# === Antivirus Results ===
# FireEye -> Detected: True  Result: Trojan.Linux.Generic.167416
# F-Secure -> Detected: True  Result: Malware.LINUX/Agent.qcvrq
# AVG -> Detected: True  Result: ELF:BruteForce-I [Trj]
# McAfee -> Detected: True  Result: GenericRXIK-UY!E2611512B4F9
# BitDefender -> Detected: True  Result: Trojan.Linux.Generic.167416
# Avast -> Detected: True  Result: ELF:BruteForce-I [Trj]
# Malwarebytes -> Detected: False  Result: None
# Microsoft -> Detected: True  Result: Trojan:Linux/CoinMiner!rfn
#
# === Scan Results ===
# Total Scans: 59
# Total Positive Results: 26
# First seen: 2020-03-17 18:26:35
# Times Submitted: 2
# Scan Permalink:  https://www.virustotal.com/file/085ae4ae11ba0200ba961b06c995249006fe0589c42ebf547e24e5987b9cb675/analysis/1588351617/
#
# === EXIF Data provided by https://exiftool.org/ ===
# File Type/Extension: GZIP (.gz)
# File Size: 3.45 MB
# Description: gzip compressed data, from Unix, last modified: Tue Mar 17 15:05:34 2020
# Target Operating System: Unix
#
# ##############################################################################################################
#
# Scanning Payload 40/1391: 087005af5673a0f6c84798766ac44c5c747416ef6f921a2d94f8ae0118947981
# Scan initiated at 2020-03-04 03:55:06
#
# All scans returned negative.
#
# === Scan Results ===
# Total Scans: 60
# Total Positive Results: 0
# First seen: 2020-03-04 03:55:06
# Times Submitted: 1
# Scan Permalink:  https://www.virustotal.com/file/087005af5673a0f6c84798766ac44c5c747416ef6f921a2d94f8ae0118947981/analysis/1583294106/
#
# === EXIF Data provided by https://exiftool.org/ ===
# File Type/Extension: GZIP (.gz)
# File Size: 1.38 MB
# Description: gzip compressed data, from Unix, last modified: Mon Mar 02 18:10:21 2020
# Target Operating System: Unix
#
# ##############################################################################################################
#
# Scanning Payload 41/1391: 08a7493aa358bac47b3deb03ec6b116421fefee64c510c867697c681b8726d09
# Scan initiated at 2020-03-04 03:34:29
#
# All scans returned negative.
#
# === Scan Results ===
# Total Scans: 58
# Total Positive Results: 0
# First seen: 2020-03-04 03:34:29
# Times Submitted: 1
# Scan Permalink:  https://www.virustotal.com/file/08a7493aa358bac47b3deb03ec6b116421fefee64c510c867697c681b8726d09/analysis/1583292869/
#
# === EXIF Data provided by https://exiftool.org/ ===
# File Type/Extension: GZIP (.gz)
# File Size: 1.86 MB
# Description: gzip compressed data, from Unix, last modified: Mon Mar 02 18:10:21 2020
# Target Operating System: Unix
#
# ##############################################################################################################
#
# JSON Decoder Error
# Scan complete
# === Scan Report ===
# 42 files were scanned
# 15 positive matches were found for malicous files
# 23 negative matches were found for malicous files
# 3 scans had no result due to files still being analysed.
# List of different file extensions found:
#    GZIP: 32
#    TXT: 3
